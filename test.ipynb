# %%
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")

# %%
# Read data from the CSV files
df_data = pd.read_csv('parking_duration_of_parking_event_vs_street_ID.csv')
#df_data = pd.read_csv('parking-small.csv')
print("Data Loaded")
# Out:
# Data Loaded

# %%
# Convert Arrival Time to datetime format
df_data['Arrival Time'] = pd.to_datetime(df_data['Arrival Time'], dayfirst=True)

# Check for errors
pd.to_datetime(df_data['Arrival Time'], errors='coerce').isnull().value_counts()

# Print datatype
print("Converted 'Arrival Time' to datetime format:")
print(df_data['Arrival Time'].dtypes)
# Out:
# Converted 'Arrival Time' to datetime format:
# datetime64[ns]

# %%
# Count Parking events on each day of the week
week_df = df_data.groupby(df_data['Arrival Time'].dt.day_name()).count().reindex(days)
week_summary = week_df['Arrival Time']
print (week_summary)
# Out:
# Arrival Time
# Monday       1827649
# Tuesday      1999064
# Wednesday    1968430
# Thursday     2046297
# Friday       2101552
# Saturday     1468669
# Sunday        796517
# Name: Arrival Time, dtype: int64

# %%
# Plot weekly event data
week_summary.plot()
# Out:
# <AxesSubplot:xlabel='Arrival Time'>

# %%
# Count Parking events on each day of the month 
ordered = ['Jan','Feb','Mar','Apr','May','June','July','Aug','Sept','Oct','Nov','Dec']
month_df = df_data.groupby(df_data['Arrival Time'].dt.month_name()).count().reindex(ordered)
month_summary = month_df['Arrival Time']
print (month_summary)
# Out:
# Arrival Time
# Jan           NaN
# Feb           NaN
# Mar           NaN
# Apr           NaN
# May     1033229.0
# June    1002630.0
# July    1024635.0
# Aug           NaN
# Sept          NaN
# Oct           NaN
# Nov           NaN
# Dec           NaN
# Name: Arrival Time, dtype: float64

# %%
# Plot monthly event data
month_summary.plot()
# Out:
# <AxesSubplot:xlabel='Arrival Time'>

# %%
df_data['months'] = pd.DatetimeIndex(df_data['Arrival Time']).month
month_summary = month_df['Arrival Time']

months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", 
          "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
df_data['months'] = pd.Categorical(df_data['months'], categories=months, ordered=True)
print (month_summary)

# %%
months = ['Jan','Feb','Mar','Apr','May','June','July','Aug','Sept','Oct','Nov','Dec']

month_df = df_data.groupby['Arrival Time'].dt.month_name()
month_summary = month_df['Arrival Time']
print (month_summary)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21576/4227934676.py in <module>
#       1 months = ['Jan','Feb','Mar','Apr','May','June','July','Aug','Sept','Oct','Nov','Dec']
#       2
# ----> 3 month_df = df_data.groupby['Arrival Time'].dt.month_name()
#       4 month_summary = month_df['Arrival Time']
#       5 print (month_summary)
#
# TypeError: 'method' object is not subscriptable

# %%
data['month'] = df_data.DatetimeIndex(data['Arrival Time']).month({'count'})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21576/66858538.py in <module>
# ----> 1 data['month'] = df_data.DatetimeIndex(data['Arrival Time']).month({'count'})
#
# C:\ProgramData\Miniconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'DatetimeIndex'
